# %%
# !pip install missingno --quiet

# %%
from sklearn import set_config
set_config(transform_output = "pandas")
import numpy as np
import pandas as pd
import missingno as msno
from datetime import datetime
import matplotlib.pyplot as plt
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.compose import ColumnTransformer
from sklearn import set_config
from sklearn.base import BaseEstimator, TransformerMixin
set_config(display='diagram')
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder, OneHotEncoder, OrdinalEncoder
from sklearn.metrics import accuracy_score
from tensorflow.keras.models import Sequential
from tensorflow.keras import models
from sklearn.impute import SimpleImputer
from tensorflow.keras.layers import Embedding, Flatten, Dense
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
import xgboost as xgb
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', '{:.5f}'.format)
import pickle
# Out:
# 2024-08-19 13:00:16.104143: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE4.1 SSE4.2 AVX AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
num_categories = 3
model = models.Sequential()
model.add(Embedding(input_dim = num_categories, output_dim = int(num_categories**0.5)+1, input_length = 1, name="embedding"))
model.add(Flatten())
model.add(Dense(256, activation="relu"))
model.add(Dense(128, activation="relu"))
model.add(Dense(64, activation="relu"))
model.add(Dense(32, activation="relu"))
model.add(Dense(1))
model.compile(loss = "mse", optimizer = "adam", metrics=["mse"])
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 1, 2)              6
#
#  flatten_5 (Flatten)         (None, 2)                 0
#
#  dense_25 (Dense)            (None, 256)               768
#
#  dense_26 (Dense)            (None, 128)               32896
#
#  dense_27 (Dense)            (None, 64)                8256
#
#  dense_28 (Dense)            (None, 32)                2080
#
#  dense_29 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 44039 (172.03 KB)
# Trainable params: 44039 (172.03 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
data = pd.read_csv('incident_event_log-Copy1.csv')
#x = int(0.05*data.shape[0])
#data = data.head(x)
data.replace('?', np.nan, inplace=True)

# Handle missing values
missing_values_dict = {col: data[col].isnull().sum() for col in data.columns if data[col].isnull().sum() > 0}
data.drop(['number', 'caller_id', 'resolved_at', 'opened_by', 'assigned_to', 'assignment_group', 
           'u_symptom', 'sys_created_at', 'sys_created_by', 'cmdb_ci', 'problem_id', 'rfc', 
           'vendor', 'caused_by'], axis=1, inplace=True)

data['closed_at'] = (pd.to_datetime(data['closed_at'], format='%d/%m/%Y %H:%M') - pd.to_datetime(data['opened_at'], format='%d/%m/%Y %H:%M')).dt.days
data['sys_updated_at'] = (pd.to_datetime(data['sys_updated_at'], format='%d/%m/%Y %H:%M') - pd.to_datetime(data['opened_at'], format='%d/%m/%Y %H:%M')).dt.days
data.drop(['opened_at'],axis=1,inplace=True)

# Define variable groups
ordinal_variable = ['incident_state', 'impact', 'urgency', 'priority', 'u_priority_confirmation', 'notify']
nominal_variable = ['active', 'made_sla', 'contact_type', 'knowledge']
to_continuous_variable = ['sys_updated_by', 'location', 'category', 'subcategory', 'closed_code', 'resolved_by']
continuous_variable = ['reassignment_count', 'reopen_count', 'sys_mod_count', 'sys_updated_at']

# Split data
X_train, X_test, y_train, y_test = train_test_split(data.drop('closed_at', axis=1), data['closed_at'],
                                                    test_size=0.3, random_state=42)


print (X_train.shape)
print (X_test.shape)
# Out:
# (99198, 20)
# (42514, 20)

# %%
# Load data
data = pd.read_csv('incident_event_log-Copy1.csv')
#x = int(0.05*data.shape[0])
#data = data.head(x)
data.replace('?', np.nan, inplace=True)

# Handle missing values
missing_values_dict = {col: data[col].isnull().sum() for col in data.columns if data[col].isnull().sum() > 0}
data.drop(['number', 'caller_id', 'resolved_at', 'opened_by', 'assigned_to', 'assignment_group', 
           'u_symptom', 'sys_created_at', 'sys_created_by', 'cmdb_ci', 'problem_id', 'rfc', 
           'vendor', 'caused_by'], axis=1, inplace=True)

data['closed_at'] = (pd.to_datetime(data['closed_at'], format='%d/%m/%Y %H:%M') - pd.to_datetime(data['opened_at'], format='%d/%m/%Y %H:%M')).dt.days
data['sys_updated_at'] = (pd.to_datetime(data['sys_updated_at'], format='%d/%m/%Y %H:%M') - pd.to_datetime(data['opened_at'], format='%d/%m/%Y %H:%M')).dt.days
data.drop(['opened_at'],axis=1,inplace=True)

# Define variable groups
ordinal_variable = ['incident_state', 'impact', 'urgency', 'priority', 'u_priority_confirmation', 'notify']
nominal_variable = ['active', 'made_sla', 'contact_type', 'knowledge']
to_continuous_variable = ['sys_updated_by', 'location', 'category', 'subcategory', 'closed_code', 'resolved_by']
continuous_variable = ['reassignment_count', 'reopen_count', 'sys_mod_count', 'sys_updated_at']

# Split data
X_train, X_test, y_train, y_test = train_test_split(data.drop('closed_at', axis=1), data['closed_at'],
                                                    test_size=0.3, random_state=42)

#print (type(X_train))


class Cat2Vec(BaseEstimator, TransformerMixin):
    def __init__(self, nominal_variable):
        self.nominal_variable = nominal_variable
        postfix='_embeddings_dict'
        for  var in self.nominal_variable:
            var_name = f"{var}{postfix}"
            #print (var_name)
            setattr(self, var_name, None)

    def fit(self, X, y=None):
        #self.y=y
        #print (type(X))
        all_embeddings_df = X[self.nominal_variable]
        #print (all_embeddings_df.head())
        print ('Inside Cat2Vec.transform()')
        for variable in self.nominal_variable:
            final_embeddings_df = pd.DataFrame()
            print ('processing ', variable)
            #for variable in nominal_variable:
            encoder = OrdinalEncoder()
            #variable = 'active'
            temp_df=pd.DataFrame()
            temp_df[variable] = X[variable]
            temp_df[variable +'_encoded']=encoder.fit_transform(temp_df[variable].to_frame())
            num_categories = len(temp_df[variable +'_encoded'].unique())
            output_dim = int(num_categories**0.5)+1
            scaler=StandardScaler()
            y_scaled = scaler.fit_transform(y.to_frame())
            #print (temp_df[variable +'_encoded'].shape)
            #print (y_scaled.shape)
            model = models.Sequential()
            model.add(Embedding(input_dim = num_categories, output_dim = int(num_categories**0.5) + 1, input_length = 1, name="embedding"))
            model.add(Flatten())
            model.add(Dense(256, activation="relu"))
            model.add(Dense(128, activation="relu"))
            model.add(Dense(64, activation="relu"))
            model.add(Dense(32, activation="relu"))
            model.add(Dense(1))
            model.compile(loss = "mse", optimizer = "adam", metrics=["mse"])
            model.fit(x = temp_df[variable +'_encoded'], y=y_scaled , epochs = 5)

            layer = model.get_layer('embedding')
            output_embeddings = layer.get_weights()
            #output_embeddings[0]
            
            embeddings_dict_name = f'self.{variable}_embeddings_dict'

            embeddings_dict = {i: list(output_embeddings[0][i]) for i in range(output_embeddings[0].shape[0])}
            
            setattr(self,embeddings_dict_name, embeddings_dict)
            

        return self

    def transform(self, X):
        #print (type(X))
        all_embeddings_df = X[self.nominal_variable]
        #print (all_embeddings_df.head())
        print ('Inside Cat2Vec.transform()')
        for variable in self.nominal_variable:
            #final_embeddings_df = pd.DataFrame()
            print ('Transforming inside cat2vec for ', variable)
            #for variable in nominal_variable:
            encoder = OrdinalEncoder()
            #variable = 'active'
            temp_df=pd.DataFrame()
            temp_df[variable] = X[variable]
            temp_df[variable +'_encoded']=encoder.fit_transform(temp_df[variable].to_frame())
            num_categories = len(temp_df[variable +'_encoded'].unique())
            output_dim = int(num_categories**0.5)+1
            #scaler=StandardScaler()
            #y_scaled = scaler.fit_transform(self.y.to_frame())
            #print (temp_df[variable +'_encoded'].shape)
            #print (y_scaled.shape)
            #model = models.Sequential()
            #model.add(Embedding(input_dim = num_categories, output_dim = int(num_categories**0.5) + 1, input_length = 1, name="embedding"))
            #model.add(Flatten())
            #model.add(Dense(256, activation="relu"))
            #model.add(Dense(128, activation="relu"))
            #model.add(Dense(64, activation="relu"))
            #model.add(Dense(32, activation="relu"))
            #model.add(Dense(1))
            #model.compile(loss = "mse", optimizer = "adam", metrics=["mse"])
            #model.fit(x = temp_df[variable +'_encoded'], y=y_scaled , epochs = 5)

            #layer = model.get_layer('embedding')
            #output_embeddings = layer.get_weights()
            #output_embeddings[0]

            #self.{variable}_embeddings_dict = {i: list(output_embeddings[0][i]) for i in range(output_embeddings[0].shape[0])}
            
            #save embeddings to use in predict step
            #with open(f'{variable}_embedding.pkl', 'wb') as f:
                #pickle.dump(embeddings_dict, f)
            embeddings_dict_name = f'self.{variable}_embeddings_dict'
            
            embeddings_dict = getattr(self,embeddings_dict_name)
            
            for index, row in temp_df.iterrows():
                for i in range(output_dim):
                    temp_df.loc[index,variable+'_embedding_'+str(i)] = embeddings_dict[temp_df.loc[index,variable+'_encoded']][i]

            #temp_df
            final_embeddings_df = temp_df.drop(columns=[variable, variable+'_encoded'])
            all_embeddings_df= pd.concat([all_embeddings_df,final_embeddings_df],axis=1)
        #all_embeddings_df.to_csv('nominal_embeddings.csv',index=True)
        all_embeddings_df.drop(self.nominal_variable, axis=1, inplace=True)
        return (all_embeddings_df)


class Cat2Vec_wpos(BaseEstimator, TransformerMixin):
    def __init__(self, ordinal_variable):
        self.ordinal_variable = ordinal_variable
        postfix='_embeddings_dict'
        for  var in self.ordinal_variable:
            var_name = f"{var}{postfix}"
            #print (var_name)
            setattr(self, var_name, None)
        postfix='_pos_embeddings_dict'
        for  var in self.ordinal_variable:
            var_name = f"{var}{postfix}"
            #print (var_name)
            setattr(self, var_name, None)
    
    def getPositionEncoding(self,seq_len, d, n=10000):
        #print (seq_len)
        P = np.zeros((seq_len, d))
        for k in range(seq_len):
            for i in np.arange(int(d/2)):
                denominator = np.power(n, 2*i/d)
                P[k, 2*i] = np.sin(k/denominator)
                P[k, 2*i+1] = np.cos(k/denominator)
        return P

    def fit(self, X, y=None):
        #self.y=y
        #print (type(X))
        all_embeddings_df = X[self.ordinal_variable]
        #print ('Inside Cat2Vec_wpos.fit()')
        for variable in self.ordinal_variable:
            print ('processing inside cat2vec_wpos for ', variable)
            final_embeddings_df = pd.DataFrame()
            #for variable in nominal_variable:
            encoder = OrdinalEncoder()
            #variable = 'active'
            temp_df=pd.DataFrame()
            temp_df[variable] = X[variable]
            temp_df[variable +'_encoded']=encoder.fit_transform(temp_df[variable].to_frame())
            num_categories = len(temp_df[variable +'_encoded'].unique())
            output_dim = int(num_categories**0.5)+1
            scaler=StandardScaler()
            y_scaled = scaler.fit_transform(y.to_frame())
            #print (temp_df[variable +'_encoded'].shape)
            #print (y_scaled.shape)
            model = models.Sequential()
            model.add(Embedding(input_dim = num_categories, output_dim = int(num_categories**0.5) + 1, input_length = 1, name="embedding"))
            model.add(Flatten())
            model.add(Dense(256, activation="relu"))
            model.add(Dense(128, activation="relu"))
            model.add(Dense(64, activation="relu"))
            model.add(Dense(32, activation="relu"))
            model.add(Dense(1))
            model.compile(loss = "mse", optimizer = "adam", metrics=["mse"])
            model.fit(x = temp_df[variable +'_encoded'], y=y_scaled , epochs = 5)

            layer = model.get_layer('embedding')
            output_embeddings = layer.get_weights()
            #output_embeddings[0]
            
            embeddings_dict_name = f'self.{variable}_embeddings_dict'

            embeddings_dict = {i: list(output_embeddings[0][i]) for i in range(output_embeddings[0].shape[0])}
            
            setattr(self,embeddings_dict_name, embeddings_dict)
            
            #with open(f'{variable}_embedding.pkl', 'wb') as f:
                #pickle.dump(embeddings_dict, f)
            
            #print (num_categories)
            
            position_embeddings = self.getPositionEncoding(seq_len=num_categories, d=output_dim, n=100)
            
            #print(position_embeddings)
            
            pos_embeddings_dict_name = f'self.{variable}_position_embeddings_dict'
            
            pos_embeddings_dict = {i: list(position_embeddings[i]) for i in range(position_embeddings.shape[0])}
            
            setattr(self,pos_embeddings_dict_name,pos_embeddings_dict)
            
            #print (position_embeddings_dict)
            
            #with open(f'{variable}_pos_embedding.pkl', 'wb') as f:
                #pickle.dump(position_embeddings_dict, f)
                
        return self
    


    def transform(self, X):
        #print (type(X))
        all_embeddings_df = X[self.ordinal_variable]
        print ('Inside Cat2Vec_wpos.transform()')
        for variable in self.ordinal_variable:
            print ('processing ', variable)
            final_embeddings_df = pd.DataFrame()
            #for variable in nominal_variable:
            encoder = OrdinalEncoder()
            #variable = 'active'
            temp_df=pd.DataFrame()
            temp_df[variable] = X[variable]
            temp_df[variable +'_encoded']=encoder.fit_transform(temp_df[variable].to_frame())
            num_categories = len(temp_df[variable +'_encoded'].unique())
            output_dim = int(num_categories**0.5)+1
            scaler=StandardScaler()
            #y_scaled = scaler.fit_transform(self.y.to_frame())
            #print (temp_df[variable +'_encoded'].shape)
            #print (y_scaled.shape)
            #model = models.Sequential()
            #model.add(Embedding(input_dim = num_categories, output_dim = int(num_categories**0.5) + 1, input_length = 1, name="embedding"))
            #model.add(Flatten())
            #model.add(Dense(256, activation="relu"))
            #model.add(Dense(128, activation="relu"))
            #model.add(Dense(64, activation="relu"))
            #model.add(Dense(32, activation="relu"))
            #model.add(Dense(1))
            #model.compile(loss = "mse", optimizer = "adam", metrics=["mse"])
            #model.fit(x = temp_df[variable +'_encoded'], y=y_scaled , epochs = 5)

            #layer = model.get_layer('embedding')
            #output_embeddings = layer.get_weights()
            #output_embeddings[0]

            #embeddings_dict = {i: list(output_embeddings[0][i]) for i in range(output_embeddings[0].shape[0])}
            
            #with open(f'{variable}_embedding.pkl', 'wb') as f:
                #pickle.dump(embeddings_dict, f)
            
            #print (num_categories)
            
            #position_embeddings = self.getPositionEncoding(seq_len=num_categories, d=output_dim, n=100)
            #print(position_embeddings)
            #position_embeddings_dict = {i: list(position_embeddings[i]) for i in range(position_embeddings.shape[0])}
            #print (position_embeddings_dict)
            
            #with open(f'{variable}_pos_embedding.pkl', 'wb') as f:
                #pickle.dump(position_embeddings_dict, f)
                
            embeddings_dict_name = f'self.{variable}_embeddings_dict'
            #print (embeddings_dict)
            pos_embeddings_dict_name = f'self.{variable}_position_embeddings_dict'
            #print (pos_embeddings_dict)
            
            embeddings_dict = getattr(self,embeddings_dict_name)
            
            pos_embeddings_dict = getattr(self,pos_embeddings_dict_name)

            for index, row in temp_df.iterrows():
                for i in range(output_dim):
                    temp_df.loc[index,variable+'_embedding_'+str(i)] = embeddings_dict[temp_df.loc[index,variable+'_encoded']][i]
                for i in range(output_dim):
                    temp_df.loc[index,variable+'_pos_embedding_'+str(i)] = pos_embeddings_dict[temp_df.loc[index,variable+'_encoded']][i]

            #temp_df
            final_embeddings_df = temp_df.drop(columns=[variable, variable+'_encoded'])
            all_embeddings_df= pd.concat([all_embeddings_df,final_embeddings_df],axis=1)
        #all_embeddings_df.to_csv('ordinal_embeddings.csv',index=True)
        all_embeddings_df.drop(self.ordinal_variable, axis=1, inplace=True)
        return (all_embeddings_df)


class ExtractNumeric(BaseEstimator, TransformerMixin):
    def fit(self, X, y=None):
        return self

    def transform(self, X):
        #print (X)
        #X = X.to_numpy()
        temp_df = pd.DataFrame()
        for col in X.columns:
            temp_df[col]=X[col].str.split().str[-1].astype(int)
        #temp_df.drop(X.columns,axis=1,inplace=True)
        #print (temp_df)
        return temp_df

# Define transformers
ordinal_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('cat2vec_wpos_encoder', Cat2Vec_wpos(ordinal_variable=ordinal_variable)),
    ('scaler',StandardScaler())
])

nominal_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('cat2vec_encoder', Cat2Vec(nominal_variable=nominal_variable)),
    ('scaler',StandardScaler())
])

contionous_transformer = Pipeline(steps=[
            ('imputer', SimpleImputer(strategy='mean')),
            ('scaler', StandardScaler())])

to_contionous_transformer = Pipeline(steps=[
            ('imputer', SimpleImputer(strategy='most_frequent')),
            ('extract_numeric', ExtractNumeric()),
            ('scaler', StandardScaler())
        ])

# Define preprocessor
preprocessor = ColumnTransformer(
    transformers=[
        ('ordinal', ordinal_transformer, ordinal_variable),
        ('nominal', nominal_transformer, nominal_variable),
        ('continuous', contionous_transformer, continuous_variable),
        ('to_continuous', to_contionous_transformer, to_continuous_variable)
    ],
    remainder='passthrough'
)

# Define models
rf_model = RandomForestRegressor(random_state=42, verbose=True)
svm_model = SVR()
xgb_model = XGBRegressor(random_state=42)

# Define pipelines
rf_pipeline = make_pipeline(preprocessor, rf_model)
svm_pipeline = make_pipeline(preprocessor, svm_model)
xgb_pipeline = make_pipeline(preprocessor, xgb_model)

# Fit pipelines
rf_pipeline.fit(X_train, y_train)
svm_pipeline.fit(X_train, y_train)
xgb_pipeline.fit(X_train, y_train)
# Out:
# processing inside cat2vec_wpos for  incident_state
# Epoch 1/5
# 3100/3100 [==============================] - 8s 2ms/step - loss: 0.9196 - mse: 0.9196
# Epoch 2/5
# 3100/3100 [==============================] - 7s 2ms/step - loss: 0.9113 - mse: 0.9113
# Epoch 3/5
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.9128 - mse: 0.9128
# Epoch 4/5
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.9098 - mse: 0.9098
# Epoch 5/5
# 3100/3100 [==============================] - 8s 2ms/step - loss: 0.9105 - mse: 0.9105
# processing inside cat2vec_wpos for  impact
# Epoch 1/5
# 3100/3100 [==============================] - 10s 3ms/step - loss: 1.0002 - mse: 1.0002
# Epoch 2/5
# 3100/3100 [==============================] - 8s 3ms/step - loss: 1.0000 - mse: 1.0000
# Epoch 3/5
# 3100/3100 [==============================] - 8s 3ms/step - loss: 1.0000 - mse: 1.0000
# Epoch 4/5
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.9999 - mse: 0.9999
# Epoch 5/5
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.9994 - mse: 0.9994
# processing inside cat2vec_wpos for  urgency
# Epoch 1/5
# 3100/3100 [==============================] - 9s 3ms/step - loss: 1.0003 - mse: 1.0003
# Epoch 2/5
# 3100/3100 [==============================] - 10s 3ms/step - loss: 1.0002 - mse: 1.0002
# Epoch 3/5
# 3100/3100 [==============================] - 8s 3ms/step - loss: 1.0001 - mse: 1.0001
# Epoch 4/5
# 3100/3100 [==============================] - 8s 3ms/step - loss: 1.0001 - mse: 1.0001
# Epoch 5/5
# 3100/3100 [==============================] - 8s 3ms/step - loss: 1.0001 - mse: 1.0001
# processing inside cat2vec_wpos for  priority
# Epoch 1/5
# 3100/3100 [==============================] - 9s 3ms/step - loss: 1.0000 - mse: 1.0000
# Epoch 2/5
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.9998 - mse: 0.9998
# Epoch 3/5
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.9999 - mse: 0.9999
# Epoch 4/5
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.9999 - mse: 0.9999
# Epoch 5/5
# 3100/3100 [==============================] - 7s 2ms/step - loss: 0.9998 - mse: 0.9998
# processing inside cat2vec_wpos for  u_priority_confirmation
# Epoch 1/5
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.9966 - mse: 0.9966
# Epoch 2/5
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.9962 - mse: 0.9962
# Epoch 3/5
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.9960 - mse: 0.9960
# Epoch 4/5
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.9961 - mse: 0.9961
# Epoch 5/5
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.9961 - mse: 0.9961
# processing inside cat2vec_wpos for  notify
# Epoch 1/5
# 3100/3100 [==============================] - 9s 3ms/step - loss: 1.0001 - mse: 1.0001
# Epoch 2/5
# 3100/3100 [==============================] - 8s 2ms/step - loss: 1.0001 - mse: 1.0001
# Epoch 3/5
# 3100/3100 [==============================] - 9s 3ms/step - loss: 1.0000 - mse: 1.0000
# Epoch 4/5
# 3100/3100 [==============================] - 8s 2ms/step - loss: 1.0001 - mse: 1.0001
# Epoch 5/5
# 3100/3100 [==============================] - 8s 3ms/step - loss: 1.0000 - mse: 1.0000
# Inside Cat2Vec_wpos.transform()
# processing  incident_state
# processing  impact
# processing  urgency
# processing  priority
# processing  u_priority_confirmation
# processing  notify
# Inside Cat2Vec.transform()
# processing  active
# Epoch 1/5
# 3100/3100 [==============================] - 10s 3ms/step - loss: 0.9965 - mse: 0.9965
# Epoch 2/5
# 3100/3100 [==============================] - 11s 4ms/step - loss: 0.9964 - mse: 0.9964
# Epoch 3/5
# 3100/3100 [==============================] - 10s 3ms/step - loss: 0.9961 - mse: 0.9961
# Epoch 4/5
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.9959 - mse: 0.9959
# Epoch 5/5
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.9961 - mse: 0.9961
# processing  made_sla
# Epoch 1/5
# 3100/3100 [==============================] - 10s 3ms/step - loss: 0.9936 - mse: 0.9936
# Epoch 2/5
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.9927 - mse: 0.9927
# Epoch 3/5
# 3100/3100 [==============================] - 10s 3ms/step - loss: 0.9925 - mse: 0.9925
# Epoch 4/5
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.9924 - mse: 0.9924
# Epoch 5/5
# 3100/3100 [==============================] - 10s 3ms/step - loss: 0.9924 - mse: 0.9924
# processing  contact_type
# Epoch 1/5
# 3100/3100 [==============================] - 11s 3ms/step - loss: 1.0001 - mse: 1.0001
# Epoch 2/5
# 3100/3100 [==============================] - 9s 3ms/step - loss: 1.0000 - mse: 1.0000
# Epoch 3/5
# 3100/3100 [==============================] - 8s 3ms/step - loss: 1.0000 - mse: 1.0000
# Epoch 4/5
# 3100/3100 [==============================] - 9s 3ms/step - loss: 1.0000 - mse: 1.0000
# Epoch 5/5
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.9999 - mse: 0.9999
# processing  knowledge
# Epoch 1/5
# 3100/3100 [==============================] - 10s 3ms/step - loss: 0.9853 - mse: 0.9853
# Epoch 2/5
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.9844 - mse: 0.9844
# Epoch 3/5
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.9840 - mse: 0.9840
# Epoch 4/5
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.9842 - mse: 0.9842
# Epoch 5/5
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.9841 - mse: 0.9841
# Inside Cat2Vec.transform()
# Transforming inside cat2vec for  active
# Transforming inside cat2vec for  made_sla
# Transforming inside cat2vec for  contact_type
# Transforming inside cat2vec for  knowledge
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:   41.7s
# processing inside cat2vec_wpos for  incident_state
# Epoch 1/5
# 3100/3100 [==============================] - 10s 3ms/step - loss: 0.9204 - mse: 0.9204
# Epoch 2/5
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.9125 - mse: 0.9125
# Epoch 3/5
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.9105 - mse: 0.9105
# Epoch 4/5
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.9097 - mse: 0.9097
# Epoch 5/5
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.9092 - mse: 0.9092
# processing inside cat2vec_wpos for  impact
# Epoch 1/5
# 3100/3100 [==============================] - 10s 3ms/step - loss: 1.0003 - mse: 1.0003
# Epoch 2/5
# 3100/3100 [==============================] - 9s 3ms/step - loss: 1.0001 - mse: 1.0001
# Epoch 3/5
# 3100/3100 [==============================] - 10s 3ms/step - loss: 1.0001 - mse: 1.0001
# Epoch 4/5
# 3100/3100 [==============================] - 10s 3ms/step - loss: 0.9998 - mse: 0.9998
# Epoch 5/5
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.9995 - mse: 0.9995
# processing inside cat2vec_wpos for  urgency
# Epoch 1/5
# 3100/3100 [==============================] - 10s 3ms/step - loss: 1.0002 - mse: 1.0002
# Epoch 2/5
# 3100/3100 [==============================] - 9s 3ms/step - loss: 1.0001 - mse: 1.0001
# Epoch 3/5
# 3100/3100 [==============================] - 9s 3ms/step - loss: 1.0001 - mse: 1.0001
# Epoch 4/5
# 3100/3100 [==============================] - 9s 3ms/step - loss: 1.0001 - mse: 1.0001
# Epoch 5/5
# 3100/3100 [==============================] - 9s 3ms/step - loss: 1.0000 - mse: 1.0000
# processing inside cat2vec_wpos for  priority
# Epoch 1/5
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.9996 - mse: 0.9996
# Epoch 2/5
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.9989 - mse: 0.9989
# Epoch 3/5
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.9988 - mse: 0.9988
# Epoch 4/5
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.9988 - mse: 0.9988
# Epoch 5/5
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.9987 - mse: 0.9987
# processing inside cat2vec_wpos for  u_priority_confirmation
# Epoch 1/5
# 3100/3100 [==============================] - 10s 3ms/step - loss: 0.9968 - mse: 0.9968
# Epoch 2/5
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.9962 - mse: 0.9962
# Epoch 3/5
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.9961 - mse: 0.9961
# Epoch 4/5
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.9959 - mse: 0.9959
# Epoch 5/5
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.9961 - mse: 0.9961
# processing inside cat2vec_wpos for  notify
# Epoch 1/5
# 3100/3100 [==============================] - 10s 3ms/step - loss: 1.0001 - mse: 1.0001
# Epoch 2/5
# 3100/3100 [==============================] - 9s 3ms/step - loss: 1.0001 - mse: 1.0001
# Epoch 3/5
# 3100/3100 [==============================] - 9s 3ms/step - loss: 1.0001 - mse: 1.0001
# Epoch 4/5
# 3100/3100 [==============================] - 9s 3ms/step - loss: 1.0001 - mse: 1.0001
# Epoch 5/5
# 3100/3100 [==============================] - 8s 3ms/step - loss: 1.0001 - mse: 1.0001
# Inside Cat2Vec_wpos.transform()
# processing  incident_state
# processing  impact
# processing  urgency
# processing  priority
# processing  u_priority_confirmation
# processing  notify
# Inside Cat2Vec.transform()
# processing  active
# Epoch 1/5
# 3100/3100 [==============================] - 10s 3ms/step - loss: 0.9967 - mse: 0.9967
# Epoch 2/5
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.9964 - mse: 0.9964
# Epoch 3/5
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.9963 - mse: 0.9963
# Epoch 4/5
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.9961 - mse: 0.9961
# Epoch 5/5
# 3100/3100 [==============================] - 10s 3ms/step - loss: 0.9960 - mse: 0.9960
# processing  made_sla
# Epoch 1/5
# 3100/3100 [==============================] - 10s 3ms/step - loss: 0.9937 - mse: 0.9937
# Epoch 2/5
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.9927 - mse: 0.9927
# Epoch 3/5
# 3100/3100 [==============================] - 10s 3ms/step - loss: 0.9927 - mse: 0.9927
# Epoch 4/5
# 3100/3100 [==============================] - 10s 3ms/step - loss: 0.9925 - mse: 0.9925
# Epoch 5/5
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.9924 - mse: 0.9924
# processing  contact_type
# Epoch 1/5
# 3100/3100 [==============================] - 11s 3ms/step - loss: 1.0001 - mse: 1.0001
# Epoch 2/5
# 3100/3100 [==============================] - 8s 3ms/step - loss: 1.0001 - mse: 1.0001
# Epoch 3/5
# 3100/3100 [==============================] - 9s 3ms/step - loss: 1.0001 - mse: 1.0001
# Epoch 4/5
# 3100/3100 [==============================] - 9s 3ms/step - loss: 1.0001 - mse: 1.0001
# Epoch 5/5
# 3100/3100 [==============================] - 9s 3ms/step - loss: 1.0001 - mse: 1.0001
# processing  knowledge
# Epoch 1/5
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.9854 - mse: 0.9854
# Epoch 2/5
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.9842 - mse: 0.9842
# Epoch 3/5
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.9842 - mse: 0.9842
# Epoch 4/5
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.9840 - mse: 0.9840
# Epoch 5/5
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.9841 - mse: 0.9841
# Inside Cat2Vec.transform()
# Transforming inside cat2vec for  active
# Transforming inside cat2vec for  made_sla
# Transforming inside cat2vec for  contact_type
# Transforming inside cat2vec for  knowledge
# processing inside cat2vec_wpos for  incident_state
# Epoch 1/5
# 3100/3100 [==============================] - 12s 3ms/step - loss: 0.9229 - mse: 0.9229
# Epoch 2/5
# 3100/3100 [==============================] - 10s 3ms/step - loss: 0.9107 - mse: 0.9107
# Epoch 3/5
# 3100/3100 [==============================] - 10s 3ms/step - loss: 0.9093 - mse: 0.9093
# Epoch 4/5
# 3100/3100 [==============================] - 10s 3ms/step - loss: 0.9109 - mse: 0.9109
# Epoch 5/5
# 3100/3100 [==============================] - 10s 3ms/step - loss: 0.9097 - mse: 0.9097
# processing inside cat2vec_wpos for  impact
# Epoch 1/5
# 3100/3100 [==============================] - 11s 3ms/step - loss: 1.0001 - mse: 1.0001
# Epoch 2/5
# 3100/3100 [==============================] - 10s 3ms/step - loss: 1.0001 - mse: 1.0001
# Epoch 3/5
# 3100/3100 [==============================] - 9s 3ms/step - loss: 1.0001 - mse: 1.0001
# Epoch 4/5
# 3100/3100 [==============================] - 10s 3ms/step - loss: 1.0001 - mse: 1.0001
# Epoch 5/5
# 3100/3100 [==============================] - 10s 3ms/step - loss: 1.0000 - mse: 1.0000
# processing inside cat2vec_wpos for  urgency
# Epoch 1/5
# 3100/3100 [==============================] - 10s 3ms/step - loss: 1.0002 - mse: 1.0002
# Epoch 2/5
# 3100/3100 [==============================] - 10s 3ms/step - loss: 1.0001 - mse: 1.0001
# Epoch 3/5
# 3100/3100 [==============================] - 9s 3ms/step - loss: 1.0001 - mse: 1.0001
# Epoch 4/5
# 3100/3100 [==============================] - 9s 3ms/step - loss: 1.0001 - mse: 1.0001
# Epoch 5/5
# 3100/3100 [==============================] - 9s 3ms/step - loss: 1.0001 - mse: 1.0001
# processing inside cat2vec_wpos for  priority
# Epoch 1/5
# 3100/3100 [==============================] - 11s 3ms/step - loss: 0.9996 - mse: 0.9996
# Epoch 2/5
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.9992 - mse: 0.9992
# Epoch 3/5
# 3100/3100 [==============================] - 10s 3ms/step - loss: 0.9998 - mse: 0.9998
# Epoch 4/5
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.9993 - mse: 0.9993
# Epoch 5/5
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.9987 - mse: 0.9987
# processing inside cat2vec_wpos for  u_priority_confirmation
# Epoch 1/5
# 3100/3100 [==============================] - 11s 3ms/step - loss: 0.9967 - mse: 0.9967
# Epoch 2/5
# 3100/3100 [==============================] - 10s 3ms/step - loss: 0.9963 - mse: 0.9963
# Epoch 3/5
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.9960 - mse: 0.9960
# Epoch 4/5
# 3100/3100 [==============================] - 10s 3ms/step - loss: 0.9961 - mse: 0.9961
# Epoch 5/5
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.9960 - mse: 0.9960
# processing inside cat2vec_wpos for  notify
# Epoch 1/5
# 3100/3100 [==============================] - 10s 3ms/step - loss: 1.0002 - mse: 1.0002
# Epoch 2/5
# 3100/3100 [==============================] - 10s 3ms/step - loss: 1.0001 - mse: 1.0001
# Epoch 3/5
# 3100/3100 [==============================] - 9s 3ms/step - loss: 1.0001 - mse: 1.0001
# Epoch 4/5
# 3100/3100 [==============================] - 9s 3ms/step - loss: 1.0001 - mse: 1.0001
# Epoch 5/5
# 3100/3100 [==============================] - 9s 3ms/step - loss: 1.0000 - mse: 1.0000
# Inside Cat2Vec_wpos.transform()
# processing  incident_state
# processing  impact
# processing  urgency
# processing  priority
# processing  u_priority_confirmation
# processing  notify
# Inside Cat2Vec.transform()
# processing  active
# Epoch 1/5
# 3100/3100 [==============================] - 10s 3ms/step - loss: 0.9967 - mse: 0.9967
# Epoch 2/5
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.9963 - mse: 0.9963
# Epoch 3/5
# 3100/3100 [==============================] - 10s 3ms/step - loss: 0.9961 - mse: 0.9961
# Epoch 4/5
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.9959 - mse: 0.9959
# Epoch 5/5
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.9960 - mse: 0.9960
# processing  made_sla
# Epoch 1/5
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.9941 - mse: 0.9941
# Epoch 2/5
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.9928 - mse: 0.9928
# Epoch 3/5
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.9926 - mse: 0.9926
# Epoch 4/5
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.9925 - mse: 0.9925
# Epoch 5/5
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.9924 - mse: 0.9924
# processing  contact_type
# Epoch 1/5
# 3100/3100 [==============================] - 10s 3ms/step - loss: 1.0001 - mse: 1.0001
# Epoch 2/5
# 3100/3100 [==============================] - 10s 3ms/step - loss: 1.0000 - mse: 1.0000
# Epoch 3/5
# 3100/3100 [==============================] - 9s 3ms/step - loss: 1.0000 - mse: 1.0000
# Epoch 4/5
# 3100/3100 [==============================] - 10s 3ms/step - loss: 1.0000 - mse: 1.0000
# Epoch 5/5
# 3100/3100 [==============================] - 8s 3ms/step - loss: 1.0000 - mse: 1.0000
# processing  knowledge
# Epoch 1/5
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.9852 - mse: 0.9852
# Epoch 2/5
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.9841 - mse: 0.9841
# Epoch 3/5
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.9841 - mse: 0.9841
# Epoch 4/5
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.9841 - mse: 0.9841
# Epoch 5/5
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.9839 - mse: 0.9839
# Inside Cat2Vec.transform()
# Transforming inside cat2vec for  active
# Transforming inside cat2vec for  made_sla
# Transforming inside cat2vec for  contact_type
# Transforming inside cat2vec for  knowledge
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ordinal',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('cat2vec_wpos_encoder',
#                                                                    Cat2Vec_wpos(ordinal_variable=['incident_state',
#                                                                                                   'impact',
#                                                                                                   'urgency',
#                                                                                                   'priority',
#                                                                                                   'u_priority_confirmation',
#                                                                                                   'notify'])),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['incide...
#                               feature_types=None, gamma=None, gpu_id=None,
#                               grow_policy=None, importance_type=None,
#                               interaction_constraints=None, learning_rate=None,
#                               max_bin=None, max_cat_threshold=None,
#                               max_cat_to_onehot=None, max_delta_step=None,
#                               max_depth=None, max_leaves=None,
#                               min_child_weight=None, missing=nan,
#                               monotone_constraints=None, n_estimators=100,
#                               n_jobs=None, num_parallel_tree=None,
#                               predictor=None, random_state=42, ...))])

# %%
# Predictions and calculate MSE
y_pred_rf = rf_pipeline.predict(X_test)
mse_rf = mean_squared_error(y_test, y_pred_rf)
#print(f"MSE for Random Forest pipeline: {mse_rf}")

y_pred_svm = svm_pipeline.predict(X_test)
mse_svm = mean_squared_error(y_test, y_pred_svm)
#print(f"MSE for SVM pipeline: {mse_svm}")

y_pred_xgb = xgb_pipeline.predict(X_test)
mse_xgb = mean_squared_error(y_test, y_pred_xgb)
#print(f"MSE for XGBoost pipeline: {mse_xgb}")

# Print MSE for Random Forest pipeline
print(f"MSE for Random Forest pipeline: {mse_rf:.3f}")

# Print MSE for SVM pipeline
print(f"MSE for SVM pipeline: {mse_svm:.3f}")

# Print MSE for XGBoost pipeline
print(f"MSE for XGBoost pipeline: {mse_xgb:.3f}")
# Out:
# Inside Cat2Vec_wpos.transform()
# processing  incident_state
# processing  impact
# processing  urgency
# processing  priority
# processing  u_priority_confirmation
# processing  notify
# Inside Cat2Vec.transform()
# Transforming inside cat2vec for  active
# Transforming inside cat2vec for  made_sla
# Transforming inside cat2vec for  contact_type
# Transforming inside cat2vec for  knowledge
# [Parallel(n_jobs=1)]: Done  49 tasks      | elapsed:    0.7s
# Inside Cat2Vec_wpos.transform()
# processing  incident_state
# processing  impact
# processing  urgency
# processing  priority
# processing  u_priority_confirmation
# processing  notify
# Inside Cat2Vec.transform()
# Transforming inside cat2vec for  active
# Transforming inside cat2vec for  made_sla
# Transforming inside cat2vec for  contact_type
# Transforming inside cat2vec for  knowledge
# Inside Cat2Vec_wpos.transform()
# processing  incident_state
# processing  impact
# processing  urgency
# processing  priority
# processing  u_priority_confirmation
# processing  notify
# Inside Cat2Vec.transform()
# Transforming inside cat2vec for  active
# Transforming inside cat2vec for  made_sla
# Transforming inside cat2vec for  contact_type
# Transforming inside cat2vec for  knowledge
# MSE for Random Forest pipeline: 316.473
# MSE for SVM pipeline: 490.337
# MSE for XGBoost pipeline: 188.299

# %%
# %%time
# Load data
data = pd.read_csv('incident_event_log-Copy1.csv')
#x = int(0.05*data.shape[0])
#data = data.head(x)
data.replace('?', np.nan, inplace=True)

# Handle missing values
missing_values_dict = {col: data[col].isnull().sum() for col in data.columns if data[col].isnull().sum() > 0}
data.drop(['number', 'caller_id', 'resolved_at', 'opened_by', 'assigned_to', 'assignment_group', 
           'u_symptom', 'sys_created_at', 'sys_created_by', 'cmdb_ci', 'problem_id', 'rfc', 
           'vendor', 'caused_by'], axis=1, inplace=True)

data['closed_at'] = (pd.to_datetime(data['closed_at'], format='%d/%m/%Y %H:%M') - pd.to_datetime(data['opened_at'], format='%d/%m/%Y %H:%M')).dt.days
data['sys_updated_at'] = (pd.to_datetime(data['sys_updated_at'], format='%d/%m/%Y %H:%M') - pd.to_datetime(data['opened_at'], format='%d/%m/%Y %H:%M')).dt.days
data.drop(['opened_at'],axis=1,inplace=True)

# Define variable groups
ordinal_variable = ['incident_state', 'impact', 'urgency', 'priority', 'u_priority_confirmation', 'notify']
nominal_variable = ['active', 'made_sla', 'contact_type', 'knowledge']
to_continuous_variable = ['sys_updated_by', 'location', 'category', 'subcategory', 'closed_code', 'resolved_by']
continuous_variable = ['reassignment_count', 'reopen_count', 'sys_mod_count', 'sys_updated_at']

# Split data
X_train, X_test, y_train, y_test = train_test_split(data.drop('closed_at', axis=1), data['closed_at'],
                                                    test_size=0.3, random_state=42)

#print (type(X_train))


class Cat2Vec(BaseEstimator, TransformerMixin):
    def __init__(self, nominal_variable):
        self.nominal_variable = nominal_variable
        postfix='_embeddings_dict'
        for  var in self.nominal_variable:
            var_name = f"{var}{postfix}"
            #print (var_name)
            setattr(self, var_name, None)

    def fit(self, X, y=None):
        #self.y=y
        #print (type(X))
        all_embeddings_df = X[self.nominal_variable]
        #print (all_embeddings_df.head())
        print ('Inside Cat2Vec.transform()')
        for variable in self.nominal_variable:
            final_embeddings_df = pd.DataFrame()
            print ('processing ', variable)
            #for variable in nominal_variable:
            encoder = OrdinalEncoder()
            #variable = 'active'
            temp_df=pd.DataFrame()
            temp_df[variable] = X[variable]
            temp_df[variable +'_encoded']=encoder.fit_transform(temp_df[variable].to_frame())
            num_categories = len(temp_df[variable +'_encoded'].unique())
            output_dim = int(num_categories**0.5)+1
            scaler=StandardScaler()
            y_scaled = scaler.fit_transform(y.to_frame())
            #print (temp_df[variable +'_encoded'].shape)
            #print (y_scaled.shape)
            model = models.Sequential()
            model.add(Embedding(input_dim = num_categories, output_dim = int(num_categories**0.5) + 1, input_length = 1, name="embedding"))
            model.add(Flatten())
            model.add(Dense(512, activation="relu"))
            model.add(Dense(256, activation="relu"))
            model.add(Dense(128, activation="relu"))
            model.add(Dense(64, activation="relu"))
            model.add(Dense(32, activation="relu"))
            model.add(Dense(1))
            model.compile(loss = "huber", optimizer = "adam", metrics=["mse"])
            model.fit(x = temp_df[variable +'_encoded'], y=y_scaled , epochs = 15)

            layer = model.get_layer('embedding')
            output_embeddings = layer.get_weights()
            #output_embeddings[0]
            
            embeddings_dict_name = f'self.{variable}_embeddings_dict'

            embeddings_dict = {i: list(output_embeddings[0][i]) for i in range(output_embeddings[0].shape[0])}
            
            setattr(self,embeddings_dict_name, embeddings_dict)
            

        return self

    def transform(self, X):
        #print (type(X))
        all_embeddings_df = X[self.nominal_variable]
        #print (all_embeddings_df.head())
        print ('Inside Cat2Vec.transform()')
        for variable in self.nominal_variable:
            #final_embeddings_df = pd.DataFrame()
            print ('Transforming inside cat2vec for ', variable)
            #for variable in nominal_variable:
            encoder = OrdinalEncoder()
            #variable = 'active'
            temp_df=pd.DataFrame()
            temp_df[variable] = X[variable]
            temp_df[variable +'_encoded']=encoder.fit_transform(temp_df[variable].to_frame())
            num_categories = len(temp_df[variable +'_encoded'].unique())
            output_dim = int(num_categories**0.5)+1
            #scaler=StandardScaler()
            #y_scaled = scaler.fit_transform(self.y.to_frame())
            #print (temp_df[variable +'_encoded'].shape)
            #print (y_scaled.shape)
            #model = models.Sequential()
            #model.add(Embedding(input_dim = num_categories, output_dim = int(num_categories**0.5) + 1, input_length = 1, name="embedding"))
            #model.add(Flatten())
            #model.add(Dense(256, activation="relu"))
            #model.add(Dense(128, activation="relu"))
            #model.add(Dense(64, activation="relu"))
            #model.add(Dense(32, activation="relu"))
            #model.add(Dense(1))
            #model.compile(loss = "mse", optimizer = "adam", metrics=["mse"])
            #model.fit(x = temp_df[variable +'_encoded'], y=y_scaled , epochs = 5)

            #layer = model.get_layer('embedding')
            #output_embeddings = layer.get_weights()
            #output_embeddings[0]

            #self.{variable}_embeddings_dict = {i: list(output_embeddings[0][i]) for i in range(output_embeddings[0].shape[0])}
            
            #save embeddings to use in predict step
            #with open(f'{variable}_embedding.pkl', 'wb') as f:
                #pickle.dump(embeddings_dict, f)
            embeddings_dict_name = f'self.{variable}_embeddings_dict'
            
            embeddings_dict = getattr(self,embeddings_dict_name)
            
            for index, row in temp_df.iterrows():
                for i in range(output_dim):
                    temp_df.loc[index,variable+'_embedding_'+str(i)] = embeddings_dict[temp_df.loc[index,variable+'_encoded']][i]

            #temp_df
            final_embeddings_df = temp_df.drop(columns=[variable, variable+'_encoded'])
            all_embeddings_df= pd.concat([all_embeddings_df,final_embeddings_df],axis=1)
        #all_embeddings_df.to_csv('nominal_embeddings.csv',index=True)
        all_embeddings_df.drop(self.nominal_variable, axis=1, inplace=True)
        return (all_embeddings_df)


class Cat2Vec_wpos(BaseEstimator, TransformerMixin):
    def __init__(self, ordinal_variable):
        self.ordinal_variable = ordinal_variable
        postfix='_embeddings_dict'
        for  var in self.ordinal_variable:
            var_name = f"{var}{postfix}"
            #print (var_name)
            setattr(self, var_name, None)
        postfix='_pos_embeddings_dict'
        for  var in self.ordinal_variable:
            var_name = f"{var}{postfix}"
            #print (var_name)
            setattr(self, var_name, None)
    
    def getPositionEncoding(self,seq_len, d, n=10000):
        #print (seq_len)
        P = np.zeros((seq_len, d))
        for k in range(seq_len):
            for i in np.arange(int(d/2)):
                denominator = np.power(n, 2*i/d)
                P[k, 2*i] = np.sin(k/denominator)
                P[k, 2*i+1] = np.cos(k/denominator)
        return P

    def fit(self, X, y=None):
        #self.y=y
        #print (type(X))
        all_embeddings_df = X[self.ordinal_variable]
        #print ('Inside Cat2Vec_wpos.fit()')
        for variable in self.ordinal_variable:
            print ('processing inside cat2vec_wpos for ', variable)
            final_embeddings_df = pd.DataFrame()
            #for variable in nominal_variable:
            encoder = OrdinalEncoder()
            #variable = 'active'
            temp_df=pd.DataFrame()
            temp_df[variable] = X[variable]
            temp_df[variable +'_encoded']=encoder.fit_transform(temp_df[variable].to_frame())
            num_categories = len(temp_df[variable +'_encoded'].unique())
            output_dim = int(num_categories**0.5)+1
            scaler=StandardScaler()
            y_scaled = scaler.fit_transform(y.to_frame())
            #print (temp_df[variable +'_encoded'].shape)
            #print (y_scaled.shape)
            model = models.Sequential()
            model.add(Embedding(input_dim = num_categories, output_dim = int(num_categories**0.5) + 1, input_length = 1, name="embedding"))
            model.add(Flatten())
            model.add(Dense(512, activation="relu"))
            model.add(Dense(256, activation="relu"))
            model.add(Dense(128, activation="relu"))
            model.add(Dense(64, activation="relu"))
            model.add(Dense(32, activation="relu"))
            model.add(Dense(1))
            model.compile(loss = "huber", optimizer = "adam", metrics=["mse"])
            model.fit(x = temp_df[variable +'_encoded'], y=y_scaled , epochs = 15)

            layer = model.get_layer('embedding')
            output_embeddings = layer.get_weights()
            #output_embeddings[0]
            
            embeddings_dict_name = f'self.{variable}_embeddings_dict'

            embeddings_dict = {i: list(output_embeddings[0][i]) for i in range(output_embeddings[0].shape[0])}
            
            setattr(self,embeddings_dict_name, embeddings_dict)
            
            #with open(f'{variable}_embedding.pkl', 'wb') as f:
                #pickle.dump(embeddings_dict, f)
            
            #print (num_categories)
            
            position_embeddings = self.getPositionEncoding(seq_len=num_categories, d=output_dim, n=100)
            
            #print(position_embeddings)
            
            pos_embeddings_dict_name = f'self.{variable}_position_embeddings_dict'
            
            pos_embeddings_dict = {i: list(position_embeddings[i]) for i in range(position_embeddings.shape[0])}
            
            setattr(self,pos_embeddings_dict_name,pos_embeddings_dict)
            
            #print (position_embeddings_dict)
            
            #with open(f'{variable}_pos_embedding.pkl', 'wb') as f:
                #pickle.dump(position_embeddings_dict, f)
                
        return self
    


    def transform(self, X):
        #print (type(X))
        all_embeddings_df = X[self.ordinal_variable]
        print ('Inside Cat2Vec_wpos.transform()')
        for variable in self.ordinal_variable:
            print ('processing ', variable)
            final_embeddings_df = pd.DataFrame()
            #for variable in nominal_variable:
            encoder = OrdinalEncoder()
            #variable = 'active'
            temp_df=pd.DataFrame()
            temp_df[variable] = X[variable]
            temp_df[variable +'_encoded']=encoder.fit_transform(temp_df[variable].to_frame())
            num_categories = len(temp_df[variable +'_encoded'].unique())
            output_dim = int(num_categories**0.5)+1
            scaler=StandardScaler()
            #y_scaled = scaler.fit_transform(self.y.to_frame())
            #print (temp_df[variable +'_encoded'].shape)
            #print (y_scaled.shape)
            #model = models.Sequential()
            #model.add(Embedding(input_dim = num_categories, output_dim = int(num_categories**0.5) + 1, input_length = 1, name="embedding"))
            #model.add(Flatten())
            #model.add(Dense(256, activation="relu"))
            #model.add(Dense(128, activation="relu"))
            #model.add(Dense(64, activation="relu"))
            #model.add(Dense(32, activation="relu"))
            #model.add(Dense(1))
            #model.compile(loss = "mse", optimizer = "adam", metrics=["mse"])
            #model.fit(x = temp_df[variable +'_encoded'], y=y_scaled , epochs = 5)

            #layer = model.get_layer('embedding')
            #output_embeddings = layer.get_weights()
            #output_embeddings[0]

            #embeddings_dict = {i: list(output_embeddings[0][i]) for i in range(output_embeddings[0].shape[0])}
            
            #with open(f'{variable}_embedding.pkl', 'wb') as f:
                #pickle.dump(embeddings_dict, f)
            
            #print (num_categories)
            
            #position_embeddings = self.getPositionEncoding(seq_len=num_categories, d=output_dim, n=100)
            #print(position_embeddings)
            #position_embeddings_dict = {i: list(position_embeddings[i]) for i in range(position_embeddings.shape[0])}
            #print (position_embeddings_dict)
            
            #with open(f'{variable}_pos_embedding.pkl', 'wb') as f:
                #pickle.dump(position_embeddings_dict, f)
                
            embeddings_dict_name = f'self.{variable}_embeddings_dict'
            #print (embeddings_dict)
            pos_embeddings_dict_name = f'self.{variable}_position_embeddings_dict'
            #print (pos_embeddings_dict)
            
            embeddings_dict = getattr(self,embeddings_dict_name)
            
            pos_embeddings_dict = getattr(self,pos_embeddings_dict_name)

            for index, row in temp_df.iterrows():
                for i in range(output_dim):
                    temp_df.loc[index,variable+'_embedding_'+str(i)] = embeddings_dict[temp_df.loc[index,variable+'_encoded']][i]
                for i in range(output_dim):
                    temp_df.loc[index,variable+'_pos_embedding_'+str(i)] = pos_embeddings_dict[temp_df.loc[index,variable+'_encoded']][i]

            #temp_df
            final_embeddings_df = temp_df.drop(columns=[variable, variable+'_encoded'])
            all_embeddings_df= pd.concat([all_embeddings_df,final_embeddings_df],axis=1)
        #all_embeddings_df.to_csv('ordinal_embeddings.csv',index=True)
        all_embeddings_df.drop(self.ordinal_variable, axis=1, inplace=True)
        return (all_embeddings_df)


class ExtractNumeric(BaseEstimator, TransformerMixin):
    def fit(self, X, y=None):
        return self

    def transform(self, X):
        #print (X)
        #X = X.to_numpy()
        temp_df = pd.DataFrame()
        for col in X.columns:
            temp_df[col]=X[col].str.split().str[-1].astype(int)
        #temp_df.drop(X.columns,axis=1,inplace=True)
        #print (temp_df)
        return temp_df

# Define transformers
ordinal_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('cat2vec_wpos_encoder', Cat2Vec_wpos(ordinal_variable=ordinal_variable)),
    ('scaler',StandardScaler())
])

nominal_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('cat2vec_encoder', Cat2Vec(nominal_variable=nominal_variable)),
    ('scaler',StandardScaler())
])

contionous_transformer = Pipeline(steps=[
            ('imputer', SimpleImputer(strategy='mean')),
            ('scaler', StandardScaler())])

to_contionous_transformer = Pipeline(steps=[
            ('imputer', SimpleImputer(strategy='most_frequent')),
            ('extract_numeric', ExtractNumeric()),
            ('scaler', StandardScaler())
        ])

# Define preprocessor
preprocessor = ColumnTransformer(
    transformers=[
        ('ordinal', ordinal_transformer, ordinal_variable),
        ('nominal', nominal_transformer, nominal_variable),
        ('continuous', contionous_transformer, continuous_variable),
        ('to_continuous', to_contionous_transformer, to_continuous_variable)
    ],
    remainder='passthrough'
)

# Define models
rf_model = RandomForestRegressor(random_state=42, max_depth=10,min_samples_split=5,min_samples_leaf=5)
svm_model = SVR()
xgb_model = XGBRegressor(random_state=42)
lr_model = LinearRegression()
knn_model = KNeighborsRegressor()

preprocessor.fit(X_train,y_train)
X_train_transformed = preprocessor.transform(X_train)
X_test_transformed = preprocessor.transform(X_test)

rf_model.fit(X_train_transformed, y_train)
svm_model.fit(X_train_transformed, y_train)
xgb_model.fit(X_train_transformed, y_train)
lr_model.fit(X_train_transformed, y_train)
knn_model.fit(X_train_transformed, y_train)


# Define pipelines
#rf_pipeline = make_pipeline(preprocessor, rf_model)
#svm_pipeline = make_pipeline(preprocessor, svm_model)
#xgb_pipeline = make_pipeline(preprocessor, xgb_model)

# Fit pipelines
#rf_pipeline.fit(X_train, y_train)
#svm_pipeline.fit(X_train, y_train)
#xgb_pipeline.fit(X_train, y_train)


# Predictions and calculate MSE for train and test sets
y_pred_train_rf = rf_model.predict(X_train_transformed)
mse_train_rf = mean_squared_error(y_train, y_pred_train_rf)


y_pred_test_rf = rf_model.predict(X_test_transformed)
mse_test_rf = mean_squared_error(y_test, y_pred_test_rf)



y_pred_train_svm = svm_model.predict(X_train_transformed)
mse_train_svm = mean_squared_error(y_train, y_pred_train_svm)


y_pred_test_svm = svm_model.predict(X_test_transformed)
mse_test_svm = mean_squared_error(y_test, y_pred_test_svm)



y_pred_train_xgb = xgb_model.predict(X_train_transformed)
mse_train_xgb = mean_squared_error(y_train, y_pred_train_xgb)


y_pred_test_xgb = xgb_model.predict(X_test_transformed)
mse_test_xgb = mean_squared_error(y_test, y_pred_test_xgb)


y_pred_train_lr = lr_model.predict(X_train_transformed)
mse_train_lr = mean_squared_error(y_train, y_pred_train_lr)

y_pred_test_lr = lr_model.predict(X_test_transformed)
mse_test_lr = mean_squared_error(y_test, y_pred_test_lr)

y_pred_train_knn = knn_model.predict(X_train_transformed)
mse_train_knn = mean_squared_error(y_train, y_pred_train_knn)

y_pred_test_knn = knn_model.predict(X_test_transformed)
mse_test_knn = mean_squared_error(y_test, y_pred_test_knn)

print (' Train MSE for all models ')
print(f"Train MSE for Random Forest : {mse_train_rf}")
print(f"Test MSE for Random Forest : {mse_test_rf}")
print(f"Train MSE for SVM : {mse_train_svm}")
print (' Test MSE for all models ')
print(f"Test MSE for SVM : {mse_test_svm}")
print(f"Train MSE for XGBoost : {mse_train_xgb}")
print(f"Test MSE for XGBoost : {mse_test_xgb}")
print(f"Train MSE for Log Reg : {mse_train_lr}")
print(f"Test MSE for Log Reg : {mse_test_lr}")
print(f"Train MSE for KNN : {mse_train_knn}")
print(f"Test MSE for KNN : {mse_test_knn}")
# Out:
# processing inside cat2vec_wpos for  incident_state
# Epoch 1/15
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.1967 - mse: 0.9404
# Epoch 2/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.1957 - mse: 0.9331
# Epoch 3/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.1953 - mse: 0.9304
# Epoch 4/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.1952 - mse: 0.9289
# Epoch 5/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.1951 - mse: 0.9297
# Epoch 6/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.1952 - mse: 0.9285
# Epoch 7/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.1951 - mse: 0.9278
# Epoch 8/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.1951 - mse: 0.9280
# Epoch 9/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.1950 - mse: 0.9281
# Epoch 10/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.1948 - mse: 0.9266
# Epoch 11/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.1947 - mse: 0.9257
# Epoch 12/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.1948 - mse: 0.9262
# Epoch 13/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.1946 - mse: 0.9256
# Epoch 14/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.1946 - mse: 0.9255
# Epoch 15/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.1947 - mse: 0.9257
# processing inside cat2vec_wpos for  impact
# Epoch 1/15
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.2064 - mse: 1.0182
# Epoch 2/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2064 - mse: 1.0183
# Epoch 3/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2064 - mse: 1.0183
# Epoch 4/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2063 - mse: 1.0182
# Epoch 5/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2063 - mse: 1.0183
# Epoch 6/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2063 - mse: 1.0182
# Epoch 7/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2064 - mse: 1.0184
# Epoch 8/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2063 - mse: 1.0182
# Epoch 9/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2063 - mse: 1.0183
# Epoch 10/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2063 - mse: 1.0182
# Epoch 11/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2063 - mse: 1.0183
# Epoch 12/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2063 - mse: 1.0183
# Epoch 13/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2063 - mse: 1.0183
# Epoch 14/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2063 - mse: 1.0182
# Epoch 15/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2063 - mse: 1.0182
# processing inside cat2vec_wpos for  urgency
# Epoch 1/15
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.2064 - mse: 1.0182
# Epoch 2/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2064 - mse: 1.0182
# Epoch 3/15
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.2064 - mse: 1.0183
# Epoch 4/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2064 - mse: 1.0184
# Epoch 5/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2063 - mse: 1.0183
# Epoch 6/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2063 - mse: 1.0182
# Epoch 7/15
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.2063 - mse: 1.0183
# Epoch 8/15
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.2063 - mse: 1.0182
# Epoch 9/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2063 - mse: 1.0182
# Epoch 10/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2063 - mse: 1.0182
# Epoch 11/15
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.2063 - mse: 1.0183
# Epoch 12/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2063 - mse: 1.0182
# Epoch 13/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2063 - mse: 1.0183
# Epoch 14/15
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.2063 - mse: 1.0183
# Epoch 15/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2063 - mse: 1.0183
# processing inside cat2vec_wpos for  priority
# Epoch 1/15
# 3100/3100 [==============================] - 10s 3ms/step - loss: 0.2064 - mse: 1.0181
# Epoch 2/15
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.2064 - mse: 1.0183
# Epoch 3/15
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.2064 - mse: 1.0182
# Epoch 4/15
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.2064 - mse: 1.0183
# Epoch 5/15
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.2063 - mse: 1.0181
# Epoch 6/15
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.2063 - mse: 1.0184
# Epoch 7/15
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.2063 - mse: 1.0182
# Epoch 8/15
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.2063 - mse: 1.0183
# Epoch 9/15
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.2063 - mse: 1.0182
# Epoch 10/15
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.2063 - mse: 1.0183
# Epoch 11/15
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.2063 - mse: 1.0183
# Epoch 12/15
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.2063 - mse: 1.0183
# Epoch 13/15
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.2063 - mse: 1.0182
# Epoch 14/15
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.2063 - mse: 1.0182
# Epoch 15/15
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.2063 - mse: 1.0182
# processing inside cat2vec_wpos for  u_priority_confirmation
# Epoch 1/15
# 3100/3100 [==============================] - 10s 3ms/step - loss: 0.2052 - mse: 1.0146
# Epoch 2/15
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.2050 - mse: 1.0144
# Epoch 3/15
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.2050 - mse: 1.0143
# Epoch 4/15
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.2050 - mse: 1.0141
# Epoch 5/15
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.2049 - mse: 1.0141
# Epoch 6/15
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.2050 - mse: 1.0142
# Epoch 7/15
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.2049 - mse: 1.0141
# Epoch 8/15
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.2049 - mse: 1.0140
# Epoch 9/15
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.2049 - mse: 1.0141
# Epoch 10/15
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.2049 - mse: 1.0142
# Epoch 11/15
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.2049 - mse: 1.0141
# Epoch 12/15
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.2049 - mse: 1.0140
# Epoch 13/15
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.2049 - mse: 1.0141
# Epoch 14/15
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.2049 - mse: 1.0140
# Epoch 15/15
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.2049 - mse: 1.0140
# processing inside cat2vec_wpos for  notify
# Epoch 1/15
# 3100/3100 [==============================] - 10s 3ms/step - loss: 0.2065 - mse: 1.0182
# Epoch 2/15
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.2064 - mse: 1.0184
# Epoch 3/15
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.2064 - mse: 1.0182
# Epoch 4/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2064 - mse: 1.0184
# Epoch 5/15
# 3100/3100 [==============================] - 8s 2ms/step - loss: 0.2064 - mse: 1.0183
# Epoch 6/15
# 3100/3100 [==============================] - 8s 2ms/step - loss: 0.2064 - mse: 1.0183
# Epoch 7/15
# 3100/3100 [==============================] - 8s 2ms/step - loss: 0.2063 - mse: 1.0184
# Epoch 8/15
# 3100/3100 [==============================] - 8s 2ms/step - loss: 0.2063 - mse: 1.0183
# Epoch 9/15
# 3100/3100 [==============================] - 8s 2ms/step - loss: 0.2063 - mse: 1.0183
# Epoch 10/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2063 - mse: 1.0183
# Epoch 11/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2063 - mse: 1.0182
# Epoch 12/15
# 3100/3100 [==============================] - 8s 2ms/step - loss: 0.2063 - mse: 1.0182
# Epoch 13/15
# 3100/3100 [==============================] - 8s 2ms/step - loss: 0.2063 - mse: 1.0183
# Epoch 14/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2063 - mse: 1.0183
# Epoch 15/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2063 - mse: 1.0183
# Inside Cat2Vec_wpos.transform()
# processing  incident_state
# processing  impact
# processing  urgency
# processing  priority
# processing  u_priority_confirmation
# processing  notify
# Inside Cat2Vec.transform()
# processing  active
# Epoch 1/15
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.2055 - mse: 1.0146
# Epoch 2/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2054 - mse: 1.0143
# Epoch 3/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2054 - mse: 1.0145
# Epoch 4/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2054 - mse: 1.0143
# Epoch 5/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2054 - mse: 1.0143
# Epoch 6/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2054 - mse: 1.0143
# Epoch 7/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2054 - mse: 1.0143
# Epoch 8/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2054 - mse: 1.0142
# Epoch 9/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2054 - mse: 1.0144
# Epoch 10/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2054 - mse: 1.0143
# Epoch 11/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2054 - mse: 1.0142
# Epoch 12/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2054 - mse: 1.0142
# Epoch 13/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2054 - mse: 1.0144
# Epoch 14/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2053 - mse: 1.0141
# Epoch 15/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2054 - mse: 1.0143
# processing  made_sla
# Epoch 1/15
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.2045 - mse: 1.0107
# Epoch 2/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2044 - mse: 1.0109
# Epoch 3/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2043 - mse: 1.0105
# Epoch 4/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2043 - mse: 1.0106
# Epoch 5/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2043 - mse: 1.0105
# Epoch 6/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2043 - mse: 1.0106
# Epoch 7/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2043 - mse: 1.0107
# Epoch 8/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2043 - mse: 1.0107
# Epoch 9/15
# 3100/3100 [==============================] - 8s 2ms/step - loss: 0.2043 - mse: 1.0106
# Epoch 10/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2043 - mse: 1.0107
# Epoch 11/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2043 - mse: 1.0107
# Epoch 12/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2043 - mse: 1.0107
# Epoch 13/15
# 3100/3100 [==============================] - 8s 2ms/step - loss: 0.2043 - mse: 1.0106
# Epoch 14/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2043 - mse: 1.0106
# Epoch 15/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2043 - mse: 1.0106
# processing  contact_type
# Epoch 1/15
# 3100/3100 [==============================] - 9s 2ms/step - loss: 0.2064 - mse: 1.0182
# Epoch 2/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2064 - mse: 1.0182
# Epoch 3/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2063 - mse: 1.0182
# Epoch 4/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2063 - mse: 1.0180
# Epoch 5/15
# 3100/3100 [==============================] - 8s 2ms/step - loss: 0.2063 - mse: 1.0180
# Epoch 6/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2063 - mse: 1.0182
# Epoch 7/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2063 - mse: 1.0181
# Epoch 8/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2063 - mse: 1.0180
# Epoch 9/15
# 3100/3100 [==============================] - 8s 2ms/step - loss: 0.2063 - mse: 1.0180
# Epoch 10/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2063 - mse: 1.0179
# Epoch 11/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2063 - mse: 1.0178
# Epoch 12/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2063 - mse: 1.0180
# Epoch 13/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2062 - mse: 1.0178
# Epoch 14/15
# 3100/3100 [==============================] - 8s 2ms/step - loss: 0.2062 - mse: 1.0180
# Epoch 15/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2062 - mse: 1.0179
# processing  knowledge
# Epoch 1/15
# 3100/3100 [==============================] - 9s 3ms/step - loss: 0.2007 - mse: 1.0025
# Epoch 2/15
# 3100/3100 [==============================] - 8s 2ms/step - loss: 0.2005 - mse: 1.0019
# Epoch 3/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2005 - mse: 1.0021
# Epoch 4/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2005 - mse: 1.0018
# Epoch 5/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2005 - mse: 1.0019
# Epoch 6/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2004 - mse: 1.0018
# Epoch 7/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2004 - mse: 1.0019
# Epoch 8/15
# 3100/3100 [==============================] - 8s 2ms/step - loss: 0.2004 - mse: 1.0018
# Epoch 9/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2004 - mse: 1.0018
# Epoch 10/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2004 - mse: 1.0017
# Epoch 11/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2004 - mse: 1.0018
# Epoch 12/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2004 - mse: 1.0018
# Epoch 13/15
# 3100/3100 [==============================] - 8s 2ms/step - loss: 0.2004 - mse: 1.0018
# Epoch 14/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2004 - mse: 1.0019
# Epoch 15/15
# 3100/3100 [==============================] - 8s 3ms/step - loss: 0.2004 - mse: 1.0017
# Inside Cat2Vec.transform()
# Transforming inside cat2vec for  active
# Transforming inside cat2vec for  made_sla
# Transforming inside cat2vec for  contact_type
# Transforming inside cat2vec for  knowledge
# Inside Cat2Vec_wpos.transform()
# processing  incident_state
# processing  impact
# processing  urgency
# processing  priority
# processing  u_priority_confirmation
# processing  notify
# Inside Cat2Vec.transform()
# Transforming inside cat2vec for  active
# Transforming inside cat2vec for  made_sla
# Transforming inside cat2vec for  contact_type
# Transforming inside cat2vec for  knowledge
# Inside Cat2Vec_wpos.transform()
# processing  incident_state
# processing  impact
# processing  urgency
# processing  priority
# processing  u_priority_confirmation
# processing  notify
# Inside Cat2Vec.transform()
# Transforming inside cat2vec for  active
# Transforming inside cat2vec for  made_sla
# Transforming inside cat2vec for  contact_type
# Transforming inside cat2vec for  knowledge
#  Train MSE for all models
# Train MSE for Random Forest : 241.24946492132042
# Test MSE for Random Forest : 282.0644866164878
# Train MSE for SVM : 400.7466273964978
#  Test MSE for all models
# Test MSE for SVM : 417.65719790059427
# Train MSE for XGBoost : 132.09556336416267
# Test MSE for XGBoost : 182.5951778703646
# Train MSE for Log Reg : 329.75789285370826
# Test MSE for Log Reg : 346.1106951456184
# Train MSE for KNN : 173.12833726486423
# Test MSE for KNN : 283.47209766194663
# CPU times: user 1h 30min 22s, sys: 4min 13s, total: 1h 34min 36s
# Wall time: 1h 8min 34s

# %%
import joblib
joblib_file = "fitted_preprocessor_0818.pkl"
joblib.dump(preprocessor, joblib_file)
# Out:
# ['fitted_preprocessor_0818.pkl']

# %%
preprocessor
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('ordinal',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('cat2vec_wpos_encoder',
#                                                   Cat2Vec_wpos(ordinal_variable=['incident_state',
#                                                                                  'impact',
#                                                                                  'urgency',
#                                                                                  'priority',
#                                                                                  'u_priority_confirmation',
#                                                                                  'notify'])),
#                                                  ('scaler', StandardScaler())]),
#                                  ['incident_state', 'impact', 'urgency',
#                                   'priorit...
#                                  Pipeline(steps=[('imputer', SimpleImputer()),
#                                                  ('scaler', StandardScaler())]),
#                                  ['reassignment_count', 'reopen_count',
#                                   'sys_mod_count', 'sys_updated_at']),
#                                 ('to_continuous',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('extract_numeric',
#                                                   ExtractNumeric()),
#                                                  ('scaler', StandardScaler())]),
#                                  ['sys_updated_by', 'location', 'category',
#                                   'subcategory', 'closed_code',
#                                   'resolved_by'])])
